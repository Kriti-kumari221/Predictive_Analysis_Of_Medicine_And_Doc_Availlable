# %%
#Importing Library

# %%
import pandas as pd      
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, confusion_matrix, classification_report
)

# %%
#Load Dataset

# %%
df = pd.read_csv("medicines_data.csv")

# %%
#data inspection

# %%
print("Shape of data:", df.shape)
# Out:
# Shape of data: (248218, 19)

# %%
print("Columns:", df.columns.tolist())
# Out:
# Columns: ['medicine_id', 'medicine_name', 'substitutes', 'uses', 'side_effects', 'chemical_class', 'therapeutic_class', 'habit_forming', 'action_class', 'city', 'area', 'pharmacy_name', 'store_stock', 'warehouse_stock', 'price', 'expiry_date', 'days_to_expiry', 'stock_status', 'needs_reorder']

# %%
df.describe()
# Out:
#          medicine_id    store_stock  warehouse_stock          price  \
# count  248218.000000  248218.000000    248218.000000  248218.000000
# mean   124109.500000     149.335713       403.094614    1290.090088
# std     71654.508896      86.583413       165.911357     699.106881
# min         1.000000       0.000000        10.000000      80.020000
# 25%     62055.250000      74.000000       279.000000     684.650000
# 50%    124109.500000     149.000000       403.000000    1288.505000
# 75%    186163.750000     224.000000       527.000000    1897.187500
# max    248218.000000     299.000000       797.000000    2500.000000
#
#        days_to_expiry  needs_reorder
# count   248218.000000  248218.000000
# mean       123.905889       0.100609
# std        376.956491       0.300811
# min       -530.000000       0.000000
# 25%       -201.000000       0.000000
# 50%        123.000000       0.000000
# 75%        450.000000       0.000000
# max        778.000000       1.000000

# %%
df.isnull().sum()
# Out:
# medicine_id               0
# medicine_name             0
# substitutes               0
# uses                      0
# side_effects              0
# chemical_class       110427
# therapeutic_class        69
# habit_forming             0
# action_class         110182
# city                      0
# area                      0
# pharmacy_name             0
# store_stock               0
# warehouse_stock           0
# price                     0
# expiry_date               0
# days_to_expiry            0
# stock_status              0
# needs_reorder             0
# dtype: int64

# %%
df=df.drop("chemical_class",axis=1)
df
# Out:
#         medicine_id                         medicine_name  \
# 0                 1              augmentin 625 duo tablet
# 1                 2                   azithral 500 tablet
# 2                 3                      ascoril ls syrup
# 3                 4                  allegra 120mg tablet
# 4                 5                        avil 25 tablet
# ...             ...                                   ...
# 248213       248214  zestrain 100mg/325mg/250mg tablet mr
# 248214       248215              zoxinace 200mg tablet sr
# 248215       248216                     zivex 25mg tablet
# 248216       248217               zi fast 500mg injection
# 248217       248218             zyvocol 1% dusting powder
#
#                                               substitutes  \
# 0       ['Penciclav 500 mg/125 mg Tablet', 'Moxikind-C...
# 1       ['Zithrocare 500mg Tablet', 'Azax 500 Tablet',...
# 2       ['Solvin LS Syrup', 'Ambrodil-LX Syrup', 'Zero...
# 3       ['Lcfex Tablet', 'Etofex 120mg Tablet', 'Nexof...
# 4                                  ['Eralet 25mg Tablet']
# ...                                                   ...
# 248213  ['Aclotec MR 100mg/325mg/250mg Tablet', 'SAMON...
# 248214  ['Algic 200mg Tablet SR', 'Topnac 200mg Tablet...
# 248215  ['HD Zine 25mg Tablet', 'Hydrocas 25mg Tablet'...
# 248216  ['Zycin 500mg Injection', 'Aziwok 500mg Inject...
# 248217  ['Canazole Dusting Powder', 'Clotrex Dusting P...
#
#                                                      uses  \
# 0                   ['Treatment of Bacterial infections']
# 1                   ['Treatment of Bacterial infections']
# 2                       ['Treatment of Cough with mucus']
# 3       ['Treatment of Sneezing and runny nose due to ...
# 4                    ['Treatment of Allergic conditions']
# ...                                                   ...
# 248213                     ['Treatment of Muscular pain']
# 248214                                   [' Pain relief']
# 248215  ['Treatment of Anxiety', 'Treatment of Skin co...
# 248216              ['Treatment of Bacterial infections']
# 248217            ['Treatment of Fungal skin infections']
#
#                                              side_effects therapeutic_class  \
# 0                      ['Vomiting', 'Nausea', 'Diarrhea']   ANTI INFECTIVES
# 1       ['Vomiting', 'Nausea', 'Abdominal pain', 'Diar...   ANTI INFECTIVES
# 2       ['Nausea', 'Vomiting', 'Diarrhea', 'Upset stom...       RESPIRATORY
# 3       ['Headache', 'Drowsiness', 'Dizziness', 'Nausea']       RESPIRATORY
# 4                      ['Sleepiness', 'Dryness in mouth']       RESPIRATORY
# ...                                                   ...               ...
# 248213  ['Nausea', 'Vomiting', 'Heartburn', 'Stomach p...   PAIN ANALGESICS
# 248214  ['Dizziness', 'Indigestion', 'Nausea', 'Abdomi...   PAIN ANALGESICS
# 248215  ['Sedation', 'Nausea', 'Vomiting', 'Upset stom...       RESPIRATORY
# 248216  ['Injection site reactions (pain, swelling, re...   ANTI INFECTIVES
# 248217  ['Blisters', 'Skin peeling', 'Swelling', 'Appl...             DERMA
#
#        habit_forming                                       action_class  \
# 0                 No                                                NaN
# 1                 No                                         Macrolides
# 2                 No                                                NaN
# 3                 No             H1 Antihistaminics (second Generation)
# 4                 No              H1 Antihistaminics (First Generation)
# ...              ...                                                ...
# 248213            No                                                NaN
# 248214            No  NSAID's- Non-Selective COX 1&2 Inhibitors (ace...
# 248215            No              H1 Antihistaminics (First Generation)
# 248216            No                                         Macrolides
# 248217            No              Fungal ergosterol synthesis inhibitor
#
#              city        area     pharmacy_name  store_stock  warehouse_stock  \
# 0       Islamabad        F-10        HealthPlus           65              119
# 1       Islamabad         I-8   Dawaai Pharmacy          247              705
# 2       Islamabad         I-8   Dawaai Pharmacy           51              190
# 3       Islamabad         I-8   Dawaai Pharmacy           65              118
# 4          Lahore     Gulberg  Servaid Pharmacy           37              343
# ...           ...         ...               ...          ...              ...
# 248213  Islamabad         F-7          MediZone           26              467
# 248214    Karachi   Nazimabad        HealthPlus          110              123
# 248215  Islamabad         F-7  Servaid Pharmacy          297              640
# 248216     Lahore  Model Town  Servaid Pharmacy           21              138
# 248217    Karachi         DHA     Fazal Medicos          266              302
#
#           price expiry_date  days_to_expiry stock_status  needs_reorder
# 0       1687.82  03-10-2026             324     in_stock              0
# 1       2486.81  03-05-2026             171     in_stock              0
# 2       1478.35  17-09-2027             673     in_stock              0
# 3       1709.60  24-12-2024            -324     in_stock              0
# 4       1792.57  14-12-2024            -334     in_stock              0
# ...         ...         ...             ...          ...            ...
# 248213  1854.40  18-07-2026             247    low_stock              1
# 248214  1416.02  23-08-2026             283     in_stock              0
# 248215   985.49  21-04-2027             524     in_stock              0
# 248216  1227.64  21-08-2024            -449    low_stock              1
# 248217  1617.24  20-07-2026             249     in_stock              0
#
# [248218 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# medicine_id               0
# medicine_name             0
# substitutes               0
# uses                      0
# side_effects              0
# therapeutic_class        69
# habit_forming             0
# action_class         110182
# city                      0
# area                      0
# pharmacy_name             0
# store_stock               0
# warehouse_stock           0
# price                     0
# expiry_date               0
# days_to_expiry            0
# stock_status              0
# needs_reorder             0
# dtype: int64

# %%
#target variable

# %%
df['is_available'] = (df['stock_status'] != 'out_of_stock').astype(int)
# If the value is NOT equal to out_of_stock returns True
# If the value iS equal to out_of_stock returns False

# %%
df['is_available']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 248213    1
# 248214    1
# 248215    1
# 248216    1
# 248217    1
# Name: is_available, Length: 248218, dtype: int64

# %%
df = df.drop("action_class",axis=1)
df
# Out:
#         medicine_id                         medicine_name  \
# 0                 1              augmentin 625 duo tablet
# 1                 2                   azithral 500 tablet
# 2                 3                      ascoril ls syrup
# 3                 4                  allegra 120mg tablet
# 4                 5                        avil 25 tablet
# ...             ...                                   ...
# 248213       248214  zestrain 100mg/325mg/250mg tablet mr
# 248214       248215              zoxinace 200mg tablet sr
# 248215       248216                     zivex 25mg tablet
# 248216       248217               zi fast 500mg injection
# 248217       248218             zyvocol 1% dusting powder
#
#                                               substitutes  \
# 0       ['Penciclav 500 mg/125 mg Tablet', 'Moxikind-C...
# 1       ['Zithrocare 500mg Tablet', 'Azax 500 Tablet',...
# 2       ['Solvin LS Syrup', 'Ambrodil-LX Syrup', 'Zero...
# 3       ['Lcfex Tablet', 'Etofex 120mg Tablet', 'Nexof...
# 4                                  ['Eralet 25mg Tablet']
# ...                                                   ...
# 248213  ['Aclotec MR 100mg/325mg/250mg Tablet', 'SAMON...
# 248214  ['Algic 200mg Tablet SR', 'Topnac 200mg Tablet...
# 248215  ['HD Zine 25mg Tablet', 'Hydrocas 25mg Tablet'...
# 248216  ['Zycin 500mg Injection', 'Aziwok 500mg Inject...
# 248217  ['Canazole Dusting Powder', 'Clotrex Dusting P...
#
#                                                      uses  \
# 0                   ['Treatment of Bacterial infections']
# 1                   ['Treatment of Bacterial infections']
# 2                       ['Treatment of Cough with mucus']
# 3       ['Treatment of Sneezing and runny nose due to ...
# 4                    ['Treatment of Allergic conditions']
# ...                                                   ...
# 248213                     ['Treatment of Muscular pain']
# 248214                                   [' Pain relief']
# 248215  ['Treatment of Anxiety', 'Treatment of Skin co...
# 248216              ['Treatment of Bacterial infections']
# 248217            ['Treatment of Fungal skin infections']
#
#                                              side_effects therapeutic_class  \
# 0                      ['Vomiting', 'Nausea', 'Diarrhea']   ANTI INFECTIVES
# 1       ['Vomiting', 'Nausea', 'Abdominal pain', 'Diar...   ANTI INFECTIVES
# 2       ['Nausea', 'Vomiting', 'Diarrhea', 'Upset stom...       RESPIRATORY
# 3       ['Headache', 'Drowsiness', 'Dizziness', 'Nausea']       RESPIRATORY
# 4                      ['Sleepiness', 'Dryness in mouth']       RESPIRATORY
# ...                                                   ...               ...
# 248213  ['Nausea', 'Vomiting', 'Heartburn', 'Stomach p...   PAIN ANALGESICS
# 248214  ['Dizziness', 'Indigestion', 'Nausea', 'Abdomi...   PAIN ANALGESICS
# 248215  ['Sedation', 'Nausea', 'Vomiting', 'Upset stom...       RESPIRATORY
# 248216  ['Injection site reactions (pain, swelling, re...   ANTI INFECTIVES
# 248217  ['Blisters', 'Skin peeling', 'Swelling', 'Appl...             DERMA
#
#        habit_forming       city        area     pharmacy_name  store_stock  \
# 0                 No  Islamabad        F-10        HealthPlus           65
# 1                 No  Islamabad         I-8   Dawaai Pharmacy          247
# 2                 No  Islamabad         I-8   Dawaai Pharmacy           51
# 3                 No  Islamabad         I-8   Dawaai Pharmacy           65
# 4                 No     Lahore     Gulberg  Servaid Pharmacy           37
# ...              ...        ...         ...               ...          ...
# 248213            No  Islamabad         F-7          MediZone           26
# 248214            No    Karachi   Nazimabad        HealthPlus          110
# 248215            No  Islamabad         F-7  Servaid Pharmacy          297
# 248216            No     Lahore  Model Town  Servaid Pharmacy           21
# 248217            No    Karachi         DHA     Fazal Medicos          266
#
#         warehouse_stock    price expiry_date  days_to_expiry stock_status  \
# 0                   119  1687.82  03-10-2026             324     in_stock
# 1                   705  2486.81  03-05-2026             171     in_stock
# 2                   190  1478.35  17-09-2027             673     in_stock
# 3                   118  1709.60  24-12-2024            -324     in_stock
# 4                   343  1792.57  14-12-2024            -334     in_stock
# ...                 ...      ...         ...             ...          ...
# 248213              467  1854.40  18-07-2026             247    low_stock
# 248214              123  1416.02  23-08-2026             283     in_stock
# 248215              640   985.49  21-04-2027             524     in_stock
# 248216              138  1227.64  21-08-2024            -449    low_stock
# 248217              302  1617.24  20-07-2026             249     in_stock
#
#         needs_reorder  is_available
# 0                   0             1
# 1                   0             1
# 2                   0             1
# 3                   0             1
# 4                   0             1
# ...               ...           ...
# 248213              1             1
# 248214              0             1
# 248215              0             1
# 248216              1             1
# 248217              0             1
#
# [248218 rows x 18 columns]

# %%
#fill with na

# %%
df['therapeutic_class'] = df['therapeutic_class'].fillna("Therapist")

# %%
df.to_csv("Medicine.csv", index=False)

# %%
cat_cols = [
    'therapeutic_class',
    'habit_forming',
    'city',
    'area',
    'pharmacy_name'
]

# %%
for c in cat_cols:
    df[c] = df[c].fillna("Unknown")

# %%
#numeric columns

# %%
num_cols = ['store_stock', 'warehouse_stock', 'price', 'days_to_expiry']
for c in num_cols:
    df[c] = df[c].fillna(df[c].median())

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
plt.figure(figsize=(4,4))
sns.countplot(x=df["is_available"])
plt.title("Medicine Availability Count")
plt.show()

# %%
for c in num_cols:
    low, high = df[c].quantile([0.01, 0.99])
    df[c] = df[c].clip(low, high)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
numeric_cols = df.select_dtypes(include=["float64", "int64"]).columns
corr_matrix = df[numeric_cols].corr()
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap", fontsize=18)
plt.show()

# %%
target_corr = corr_matrix["is_available"].sort_values(ascending=False)
print("Correlation With Target:\n")
print(target_corr)
before=df.copy()
# Out:
# Correlation With Target:
#
# is_available       1.000000
# store_stock        0.097766
# warehouse_stock    0.050098
# price              0.002649
# medicine_id        0.002478
# days_to_expiry     0.001353
# needs_reorder     -0.171711
# Name: is_available, dtype: float64

# %%
feature_cols = num_cols + cat_cols

X = df[feature_cols]
y = df['is_available']

# %%
feature_cols
# Out:
# ['store_stock',
#  'warehouse_stock',
#  'price',
#  'days_to_expiry',
#  'therapeutic_class',
#  'habit_forming',
#  'city',
#  'area',
#  'pharmacy_name']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
#under-sampling

# %%
train_df = X_train.copy()
train_df['is_available'] = y_train.values

# %%
# minority = train_df[train_df['is_available'] == 0]
# majority = train_df[train_df['is_available'] == 1]#filters the DataFrame to get only rows where is_available = 0

# %%
# ratio = 5  # keep majority efines a ratio of 2:1 (majority:minority)
# majority_sampled = majority.sample(n=len(minority) * ratio, random_state=42)#frac=1.0 means "return 100% of the rows" (i.e., all rows)
# #sample frac=1.0 randomly shuffles all rows

# %%
# balanced_df = pd.concat([minority, majority_sampled], axis=0)
# balanced_df = balanced_df.sample(frac=1.0, random_state=42)#suflling the rows

# %%
# X_train_bal = balanced_df[feature_cols]
# y_train_bal = balanced_df['is_available']
# --------------------------
# Apply SMOTE balancing here
# --------------------------
from imblearn.over_sampling import SMOTENC
cat_cols = ['therapeutic_class', 'habit_forming', 'city', 'area', 'pharmacy_name']
categorical_indices = [X.columns.get_loc(col) for col in cat_cols]

sm = SMOTENC(categorical_features=categorical_indices, random_state=42)

X_train_bal, y_train_bal = sm.fit_resample(X_train, y_train)


print("Before SMOTE:", X_train.shape, y_train.value_counts().to_dict())
print("After SMOTE:", X_train_bal.shape, y_train_bal.value_counts().to_dict())
# Out:
# Before SMOTE: (198574, 9) {1: 197921, 0: 653}
# After SMOTE: (395842, 9) {1: 197921, 0: 197921}

# %%
plt.figure(figsize=(4,4))
sns.countplot(x=y_train_bal)
plt.title("Balanced Training Data Count (SMOTE)")
plt.show()

# %%
num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])
#making pipeline for using the scaler in future

# %%
cat_transformer = OneHotEncoder(handle_unknown='ignore')

# %%
preprocess = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_cols),
        ('cat', cat_transformer, cat_cols)
    ]
)

# %%
#models

# %%
models = {
    "LogisticRegression": LogisticRegression(
        max_iter=500,        # important for convergence
        random_state=42
    )
}

for name, model in models.items():
    clf = Pipeline(steps=[
        ('preprocess', preprocess),
        ('model', model)
    ])
    print(f"{name} pipeline created successfully")
# Out:
# LogisticRegression pipeline created successfully

# %%
#fit data

# %%
clf.fit(X_train_bal, y_train_bal)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['store_stock',
#                                                    'warehouse_stock', 'price',
#                                                    'days_to_expiry']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['therapeutic_class',
#                                                    'habit_forming', 'city',
#                                                    'area',
#                                                    'pharmacy_name'])])),
#                 ('model', LogisticRegression(max_iter=500, random_state=42))])

# %%
#predict

# %%
y_pred = clf.predict(X_test)

# %%
y_proba = clf.predict_proba(X_test)[:, 1]

# %%
#accuracy metrice

# %%
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc = roc_auc_score(y_test, y_proba)

# %%
 ##acc = accuracy_score(y_test, y_pred)
print("Accuracy :", acc)
# Out:
# Accuracy : 0.9786076867295141

# %%
print("Precision:", prec)
# Out:
# Precision: 0.999979347803639

# %%
print("Recall   :", rec)
# Out:
# Recall   : 0.9785574260827389

# %%
print("F1-score :", f1)
# Out:
# F1-score : 0.9891524177238463

# %%
print("ROC-AUC  :", roc)
# Out:
# ROC-AUC  : 0.9956096428163602

# %%
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[  162     1]
#  [ 1061 48420]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
y_prob = clf.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--', label="Random Guessing")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC–AUC Curve for best model")
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
#predict function

# %%
#confusion mertics

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(clf, X_test, y_test)
plt.title("Confusion Matrix (Best Model)")
plt.show()

# %%
def check_medicine_availability(sample):
    sample_df = pd.DataFrame([sample])
    pred = clf.predict(sample_df)[0]
    proba = clf.predict_proba(sample_df)[0][1]
    status = "AVAILABLE" if pred == 1 else "OUT OF STOCK"
    print("Prediction:", status)
    print("Probability available:", proba)

    return status, proba

# %%
example = {
    "store_stock": 0,
    "warehouse_stock": 10,
    "price": 120,
    "days_to_expiry": 90,
    "therapeutic_class": "Therapist",
    "habit_forming": "No",
    "city": "Lahore",
    "area": "Johar Town",
    "pharmacy_name": "ABC Pharmacy"
}

# %%
#checking

# %%
check_medicine_availability(example)
# Out:
# Prediction: OUT OF STOCK
# Probability available: 1.3078484655691486e-05
# ('OUT OF STOCK', np.float64(1.3078484655691486e-05))

# %%
example = {
    "store_stock": 150,
    "warehouse_stock": 120,
    "price": 85.50,
    "days_to_expiry": 180,
    "therapeutic_class": "Pain Reliever",
    "habit_forming": "No",
    "city": "Mumbai",
    "area": "Andheri East",
    "pharmacy_name": "Apollo Pharmacy"
}

# %%
check_medicine_availability(example)
# Out:
# Prediction: AVAILABLE
# Probability available: 1.0
# ('AVAILABLE', np.float64(1.0))
